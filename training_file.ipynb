# %%
# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib

# !pip install -q pycocotools

# !pip install tensorflow==1.15.0

# %cd /content/drive/My Drive/obj_detec/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH'] += ':content/drive/My Drive/obj_detec/models/research/:content/drive/My Drive/obj_detec/models/research/slim/'

# %%
! python setup.py install

# %%
! export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim
! protoc object_detection/protos/*.proto --python_out=.

# %%
model_dir = 'Training_record/training_result'

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/My\ Drive/obj_detec/models/research/Training_record/training_result/

# %%
# %cd /content/drive/My Drive
# %cd obj_detec
# %cd PyYAML

! python setup.py --with-libyaml install

# %%
#! pip install -U PyYAML
# %cd /content/drive/My Drive/obj_detec/models/research

! python train.py logtostderr --train_dir=/content/drive/My\ Drive/obj_detec/models/research/Training_record/training_result --pipeline_config_path=/content/drive/My\ Drive/obj_detec/models/research/Training_record/faster_rcnn_pipeline.config

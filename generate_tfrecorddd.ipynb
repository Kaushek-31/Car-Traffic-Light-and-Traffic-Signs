# %%
! pip install tensorflow==1.15.0
# Out:
# ...
#      |████████████████████████████████| 412.3MB 41kB/s
# ...
#      |████████████████████████████████| 3.8MB 41.7MB/s
# ...
#      |████████████████████████████████| 51kB 6.7MB/s
# ...
#      |████████████████████████████████| 512kB 43.1MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7542 sha256=ef2549f52bfd2f7141abcd00737df63b334ecfdbf3c1776d33043727cf1ee6d5
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
# ...

# %%
# %cd /content/drive/My Drive/obj_detec/models/research
! python generate_tfrecord.py --csv_input=Dataset/test_drive.csv  --output_path=test_data.record
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/My Drive/obj_detec/models/research/Dataset/car/test/1479500598118161140.jpg
# Completed - 35.175097276264594
# /content/drive/My Drive/obj_detec/models/research/Dataset/car/test/1479500598618651941.jpg
# Completed - 35.20103761348898
# /content/drive/My Drive/obj_detec/models/research/Dataset/car/test/1479500599595919701.jpg
# Completed - 35.22697795071336
# /content/drive/My Drive/obj_detec/models/research/Dataset/car/test/1479500600116489238.jpg
# Completed - 35.252918287937746
# /content/drive/My Drive/obj_detec/models/research/Dataset/car/test/1479500600618436838.jpg
# Completed - 35.27885862516213
# /content/drive/My Drive/obj_detec/models/research/Dataset/car/test/1479500601616199081.jpg
# Completed - 35.30479896238651
# /content/drive/My Drive/obj_detec/models/research/Dataset/car/test/1479500602615954278.jpg
# Completed - 35.3307392996109
# ...
